# %%
import scipy.integrate as integrate
import numpy as np

# %%
result = integrate.quad(lambda x: 1/np.sqrt(x), 0, 1, full_output=100,epsabs=1e-3,epsrel=1e-3)
result
# Out:
# (1.9999999999999984,
#  5.773159728050814e-15,
#  {'neval': 231,
#   'last': 6,
#   'iord': array([         1,          2,          3,          4,          5,
#                   6,   68391664,      32530,   35466288,      32530,
#          1461890784,      22093,   24642752,      32530, 1461890720,
#               22093,   65708400,      32530,   67607792,      32530,
#            24646416,      32530,   68127088,      32530,   67932784,
#               32530,   68294640,      32530,   68294768,      32530,
#            67336176,      32530,   25597232,      32530,   24594032,
#               32530,   24594736,      32530,   68190768,      32530,
#            66941104,      32530,   24643440,      32530,   35276976,
#               32530,   67883952,      32530,        208,          0],
#         dtype=int32),
#   'alist': array([0.00000000e+000, 5.00000000e-001, 2.50000000e-001, 1.25000000e-001,
#          6.25000000e-002, 3.12500000e-002, 4.35994229e-015, 3.64643321e-015,
# ...

# %%
result = integrate.quad(lambda x: np.log(x)/np.sqrt(x), 0, 1, full_output=100)
result
# Out:
# (-4.000000000000085,
#  1.354472090042691e-13,
#  {'neval': 315,
#   'last': 8,
#   'iord': array([          1,           4,           5,           6,           3,
#                    7,           8,           2,    23394288,       32530,
#             23944928,       32530,  1272254962,  -950781502,    23938112,
#                32530,    23286688,       32530,  1543128022,  -961273306,
#             65857264,       32530,    23192816,       32530, -1464167693,
#           -880698301,    23939152,       32530,    23193536,       32530,
#            735301551,     9653445,    35622960,       32530,    23193296,
#                32530, -1396084135,  2096951812,    23392496,       32530,
#             23194064,       32530,   279627781,  -726609924,    35213168,
#                32530,    23194256,       32530,         352,           0],
#         dtype=int32),
#   'alist': array([0.00000000e+000, 5.00000000e-001, 2.50000000e-001, 1.25000000e-001,
# ...
